# %%
import pandas as pd
import numpy as np

data = {
    'patient_id': [101, 102, 103, 104, 105, 106, 107, 108, 109, 110,
                   111, 112, 113, 114, 115, 101, 107, 118, 119, 120],
    'age': ['25', '34', None, '45', '29', None, '38', '52', '27', '41',
            '33', 'unknown', '48', '26', '35', '25', '38', '31', None, '44'],
    'weight': ['70', '65', '80', None, '75', None, '68', '90', '72', '85',
               '78', None, '82', '69', 'N/A', '70', '68', '74', None, '88'],
    'blood_pressure': [120, 130, None, 140, 125, None, 135, None, 118, 145,
                      128, None, 138, 122, None, 120, 135, 126, None, 142],
    'medication': ['Aspirin', 'Metformin', 'Lisinopril', None, 'Aspirin',
                   'Metformin', 'Lisinopril', 'Aspirin', None, 'Metformin',
                   'Lisinopril', 'Aspirin', None, 'Metformin', 'Aspirin',
                   'Aspirin', 'Lisinopril', 'Metformin', 'Aspirin', None],
    'insurance_provider': ['Blue Cross', 'Aetna', 'Cigna', 'UnitedHealth', None,
                          'Blue Cross', 'Aetna', 'Cigna', 'UnitedHealth', 'Blue Cross',
                          'Aetna', None, 'UnitedHealth', 'Blue Cross', 'Aetna',
                          'Blue Cross', 'Aetna', 'Cigna', 'UnitedHealth', None]
}

df = pd.DataFrame(data)

# %% [markdown]
# Task 1 — Inspect the Data

# %%
import pandas as pd
import numpy as np

data = {
    'patient_id': [101, 102, 103, 104, 105, 106, 107, 108, 109, 110,
                   111, 112, 113, 114, 115, 101, 107, 118, 119, 120],
    'age': ['25', '34', None, '45', '29', None, '38', '52', '27', '41',
            '33', 'unknown', '48', '26', '35', '25', '38', '31', None, '44'],
    'weight': ['70', '65', '80', None, '75', None, '68', '90', '72', '85',
               '78', None, '82', '69', 'N/A', '70', '68', '74', None, '88'],
    'blood_pressure': [120, 130, None, 140, 125, None, 135, None, 118, 145,
                      128, None, 138, 122, None, 120, 135, 126, None, 142],
    'medication': ['Aspirin', 'Metformin', 'Lisinopril', None, 'Aspirin',
                   'Metformin', 'Lisinopril', 'Aspirin', None, 'Metformin',
                   'Lisinopril', 'Aspirin', None, 'Metformin', 'Aspirin',
                   'Aspirin', 'Lisinopril', 'Metformin', 'Aspirin', None],
    'insurance_provider': ['Blue Cross', 'Aetna', 'Cigna', 'UnitedHealth', None,
                          'Blue Cross', 'Aetna', 'Cigna', 'UnitedHealth', 'Blue Cross',
                          'Aetna', None, 'UnitedHealth', 'Blue Cross', 'Aetna',
                          'Blue Cross', 'Aetna', 'Cigna', 'UnitedHealth', None]
}

df = pd.DataFrame(data)

# %% [markdown]
# Task 2 — Data Type Conversion

# %%
df['age'] = pd.to_numeric(df['age'], errors='coerce')
df['weight'] = pd.to_numeric(df['weight'], errors='coerce')
df['insurance_provider'] = df['insurance_provider'].astype('category')

# %% [markdown]
# Task 3 — Handle Missing Values

# %%
# Fill age with median
df['age'] = df['age'].fillna(df['age'].median())

# Fill weight with median
df['weight'] = df['weight'].fillna(df['weight'].median())

# Fill blood pressure with median
df['blood_pressure'] = df['blood_pressure'].fillna(df['blood_pressure'].median())

# Fill medication with mode
df['medication'] = df['medication'].fillna(df['medication'].mode()[0])

# Fix category issue
df['insurance_provider'] = df['insurance_provider'].cat.add_categories('Unknown')
df['insurance_provider'] = df['insurance_provider'].fillna('Unknown')

# Verify missing values
print(df.isnull().sum())
# Out:
# patient_id            0
# age                   0
# weight                0
# blood_pressure        0
# medication            0
# insurance_provider    0
# dtype: int64

# %% [markdown]
# Task 4 — Handle Duplicates

# %%
# Show duplicate rows
print("\nDuplicate Rows:")
print(df[df.duplicated(keep=False)])

# Identify duplicates based on patient_id
print("\nDuplicates based on patient_id:")
print(df[df.duplicated(subset=['patient_id'], keep=False)])

# Shape before removal
print("\nShape before removing duplicates:", df.shape)

# Remove duplicates
df = df.drop_duplicates(subset=['patient_id'], keep='first')

# Shape after removal
print("Shape after removing duplicates:", df.shape)
# Out:
# Duplicate Rows:
#     patient_id   age  weight  blood_pressure  medication insurance_provider
# 0          101  25.0    70.0           120.0     Aspirin         Blue Cross
# 6          107  38.0    68.0           135.0  Lisinopril              Aetna
# 15         101  25.0    70.0           120.0     Aspirin         Blue Cross
# 16         107  38.0    68.0           135.0  Lisinopril              Aetna
#
# Duplicates based on patient_id:
#     patient_id   age  weight  blood_pressure  medication insurance_provider
# 0          101  25.0    70.0           120.0     Aspirin         Blue Cross
# 6          107  38.0    68.0           135.0  Lisinopril              Aetna
# 15         101  25.0    70.0           120.0     Aspirin         Blue Cross
# 16         107  38.0    68.0           135.0  Lisinopril              Aetna
#
# Shape before removing duplicates: (20, 6)
# Shape after removing duplicates: (18, 6)

# %% [markdown]
# Task 5 — Complete Workflow with Verification

# %%
# Import libraries (IMPORTANT)
import pandas as pd
import numpy as np

# Reload dataset
data = {
    'patient_id': [101,102,103,104,105,106,107,108,109,110,
                   111,112,113,114,115,101,107,118,119,120],
    'age': ['25','34',None,'45','29',None,'38','52','27','41',
            '33','unknown','48','26','35','25','38','31',None,'44'],
    'weight': ['70','65','80',None,'75',None,'68','90','72','85',
               '78',None,'82','69','N/A','70','68','74',None,'88'],
    'blood_pressure': [120,130,None,140,125,None,135,None,118,145,
                       128,None,138,122,None,120,135,126,None,142],
    'medication': ['Aspirin','Metformin','Lisinopril',None,'Aspirin',
                   'Metformin','Lisinopril','Aspirin',None,'Metformin',
                   'Lisinopril','Aspirin',None,'Metformin','Aspirin',
                   'Aspirin','Lisinopril','Metformin','Aspirin',None],
    'insurance_provider': ['Blue Cross','Aetna','Cigna','UnitedHealth',None,
                           'Blue Cross','Aetna','Cigna','UnitedHealth','Blue Cross',
                           'Aetna',None,'UnitedHealth','Blue Cross','Aetna',
                           'Blue Cross','Aetna','Cigna','UnitedHealth',None]
}

df = pd.DataFrame(data)

# Create copy
df_clean = df.copy()

# -------- BEFORE CLEANING --------
shape_before = df_clean.shape
missing_before = df_clean.isnull().sum()
duplicates_before = df_clean.duplicated(subset=['patient_id']).sum()
dtypes_before = df_clean.dtypes


# -------- Data Type Conversion --------
df_clean['age'] = pd.to_numeric(df_clean['age'], errors='coerce')
df_clean['weight'] = pd.to_numeric(df_clean['weight'], errors='coerce')


# -------- Handle Missing Values --------
df_clean['age'].fillna(df_clean['age'].median(), inplace=True)
df_clean['weight'].fillna(df_clean['weight'].median(), inplace=True)
df_clean['blood_pressure'].fillna(df_clean['blood_pressure'].median(), inplace=True)

df_clean['medication'].fillna(df_clean['medication'].mode()[0], inplace=True)

df_clean['insurance_provider'].fillna('Unknown', inplace=True)
df_clean['insurance_provider'] = df_clean['insurance_provider'].astype('category')


# -------- Remove Duplicates --------
df_clean = df_clean.drop_duplicates(subset=['patient_id'], keep='first')


# -------- AFTER CLEANING --------
shape_after = df_clean.shape
missing_after = df_clean.isnull().sum()
duplicates_after = df_clean.duplicated(subset=['patient_id']).sum()
dtypes_after = df_clean.dtypes


# -------- Verification Report --------
print("===== VERIFICATION REPORT =====")

print("\nShape Before:", shape_before)
print("Shape After:", shape_after)

print("\nMissing Values Before:\n", missing_before)
print("\nMissing Values After:\n", missing_after)

print("\nDuplicates Before:", duplicates_before)
print("Duplicates After:", duplicates_after)

print("\nData Types Before:\n", dtypes_before)
print("\nData Types After:\n", dtypes_after)
# Out:
# ===== VERIFICATION REPORT =====
#
# Shape Before: (20, 6)
# Shape After: (18, 6)
#
# Missing Values Before:
#  patient_id            0
# age                   3
# weight                4
# blood_pressure        6
# medication            4
# insurance_provider    3
# dtype: int64
#
# Missing Values After:
#  patient_id            0
# age                   0
# weight                0
# blood_pressure        0
# medication            0
# insurance_provider    0
# dtype: int64
#
# Duplicates Before: 2
# Duplicates After: 0
#
# Data Types Before:
#  patient_id              int64
# age                    object
# weight                 object
# blood_pressure        float64
# medication             object
# insurance_provider     object
# dtype: object
#
# Data Types After:
#  patient_id               int64
# age                    float64
# weight                 float64
# blood_pressure         float64
# medication              object
# insurance_provider    category
# dtype: object
# /tmp/ipykernel_1093/3189823870.py:43: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_clean['age'].fillna(df_clean['age'].median(), inplace=True)
# /tmp/ipykernel_1093/3189823870.py:44: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_clean['weight'].fillna(df_clean['weight'].median(), inplace=True)
# /tmp/ipykernel_1093/3189823870.py:45: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_clean['blood_pressure'].fillna(df_clean['blood_pressure'].median(), inplace=True)
# /tmp/ipykernel_1093/3189823870.py:47: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_clean['medication'].fillna(df_clean['medication'].mode()[0], inplace=True)
# /tmp/ipykernel_1093/3189823870.py:49: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_clean['insurance_provider'].fillna('Unknown', inplace=True)
